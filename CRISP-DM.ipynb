# %%
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('display.max_columns', 200)

# %% [markdown]
# ## Data

# %%
data = pd.read_csv('data/listings.csv')
data.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3781  https://www.airbnb.com/rooms/3781  20190714024644   2019-07-14
# 1  5506  https://www.airbnb.com/rooms/5506  20190714024644   2019-07-14
# 2  6695  https://www.airbnb.com/rooms/6695  20190714024644   2019-07-14
# 3  6976  https://www.airbnb.com/rooms/6976  20190714024644   2019-07-14
# 4  8789  https://www.airbnb.com/rooms/8789  20190714024644   2019-07-14
#
#                                                name  \
# 0                         HARBORSIDE-Walk to subway
# 1    **$99 Special **   Private! Minutes to center!
# 2                    $99 Special!! Home Away! Condo
# 3  Mexican Folk Art Showcase in Boston Neighborhood
# 4               Curved Glass Studio/1bd facing Park
#
#                                              summary  \
# 0  Fully separate apartment in a two apartment bu...
# 1  This is a private guest room with private bath...
# ...

# %% [markdown]
# ### Shape

# %%
data.shape
# Out:
# (6264, 106)

# %% [markdown]
# ### Columns

# %% [markdown]
# ### Description

# %%
data.describe(include='all')
# Out:
#                   id                            listing_url     scrape_id  \
# count   6.264000e+03                                   6264  6.264000e+03
# unique           NaN                                   6264           NaN
# top              NaN  https://www.airbnb.com/rooms/12368012           NaN
# freq             NaN                                      1           NaN
# mean    2.084897e+07                                    NaN  2.019071e+13
# std     9.885939e+06                                    NaN  2.859603e+00
# min     3.781000e+03                                    NaN  2.019071e+13
# 25%     1.378730e+07                                    NaN  2.019071e+13
# 50%     2.172642e+07                                    NaN  2.019071e+13
# 75%     2.903044e+07                                    NaN  2.019071e+13
# max     3.669705e+07                                    NaN  2.019071e+13
#
#        last_scraped                                              name  \
# ...

# %% [markdown]
# ### Correlations

# %%
sns.heatmap(data[['id', 
                  'beds', 
                  'accommodates', 
                  'bathrooms', 
                  'bedrooms', 
                  'price', 
                  'weekly_price', 
                  'monthly_price', 
                  'review_scores_rating', 
                  'review_scores_accuracy', 
                  'reviews_per_month']].corr(), annot=True, fmt=".2f")

# %% [markdown]
# ### NaN Distribution
# From the looks of it that 9 columns are close to be NaN values.

# %%
nan_distribution = data.isna().mean().sort_values(ascending=False).to_frame().rename(columns={0:'naCounts'})
nan_distribution
# Out:
#                                               naCounts
# neighbourhood_group_cleansed                  1.000000
# host_acceptance_rate                          1.000000
# xl_picture_url                                1.000000
# medium_url                                    1.000000
# thumbnail_url                                 1.000000
# license                                       0.998084
# square_feet                                   0.979246
# monthly_price                                 0.926564
# weekly_price                                  0.923372
# access                                        0.405651
# notes                                         0.399904
# interaction                                   0.366220
# transit                                       0.351852
# host_about                                    0.342433
# house_rules                                   0.319125
# neighborhood_overview                         0.317529
# ...

# %%
nan_distribution.loc[['id', 'beds', 'accommodates', 'bathrooms', 'bedrooms', 'price', 'weekly_price', 'monthly_price', 'review_scores_rating', 'review_scores_accuracy', 'reviews_per_month']]
# Out:
#                         naCounts
# id                      0.000000
# beds                    0.000000
# accommodates            0.000000
# bathrooms               0.000479
# bedrooms                0.000319
# price                   0.000000
# weekly_price            0.923372
# monthly_price           0.926564
# review_scores_rating    0.196520
# review_scores_accuracy  0.196999
# reviews_per_month       0.187580

# %%
data['']
